# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %%
plot_points = pd.read_csv('result.csv')
plot_test_points = pd.read_csv('test.csv')

# %%
plt.figure(figsize=(15, 7))
plot_chart = sns.lineplot(x="t",
                         y="x",
                         data=plot_points)
plot_test_chart = sns.lineplot(x="t",
                         y="x",
                         data=plot_test_points)
plt.show()
